# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("scraped_data.db")

df = pd.read_sql_query("SELECT * FROM reviews", conn)
df.shape
# Out:
# (6945, 13)

# %%
from spacy.tokenizer import Tokenizer
from spacy.lang.en import English

nlp = English()
tokenizer = nlp.tokenizer

def tokenize_text(text):
    if isinstance(text, str):
        return [token.text for token in tokenizer(text)]
    else:
        return []

df['Tokenized_Long_Text'] = df['Long_Text'].apply(tokenize_text)

# %%
df.head()
# Out:
#                                      ID  \
# 0  aad9a4c3-8a9b-4789-b239-8d6872da6b7e
# 1  3b738a45-14a4-4e9f-9c50-c37458bb5844
# 2  85dfd49f-59ce-45cb-8b86-657c001455de
# 3  dc47b511-7668-4107-b7c0-8c63266ac963
# 4  003f6d65-549f-477c-822b-6f57a8a9105e
#
#                                                  URL           Scraped_at  \
# 0  https://www.ign.com/articles/arcs-board-game-r...  2025-03-30 15:20:27
# 1  https://www.ign.com/articles/elden-ring-shadow...  2025-03-30 15:20:29
# 2  https://www.ign.com/articles/stardew-valley-re...  2025-03-30 15:20:30
# 3  https://www.ign.com/articles/asgards-wrath-2-r...  2025-03-30 15:20:31
# 4  https://www.ign.com/articles/baldurs-gate-3-re...  2025-03-30 15:20:32
#
#               Author                    Posted                  Modified  \
# 0       Matt Thrower  2024-11-13T15:10:01.708Z  2024-11-13T15:20:56.240Z
# 1  Mitchell Saltzman  2024-06-18T14:00:00.000Z  2024-06-25T22:46:45.861Z
# 2     Shailyn Cotten  2024-05-07T16:00:00.000Z  2024-07-12T17:14:15.989Z
# 3     Travis Northup  2023-12-14T14:00:00.000Z  2023-12-14T20:40:01.659Z
# 4        Leana Hafer  2023-08-18T23:32:25.376Z  2024-01-31T19:38:28.947Z
#
#                                           Title  \
# 0                        Arcs Board Game Review
# 1  Elden Ring: Shadow of the Erdtree DLC Review
# 2                  Stardew Valley Review - 2024
# 3                       Asgard’s Wrath 2 Review
# 4                        Baldur's Gate 3 Review
#
#                                             Subtitle  Score  \
# 0           A deviously deep game of space conquest.   10.0
# 1                                       Untarnished.   10.0
# 2  Eight years of impressive updates have grown S...   10.0
# 3  This open-world action RPG sets a new gold sta...   10.0
# 4  A new high-water mark for CRPGs with satisfyin...   10.0
#
#                                              Verdict  \
# 0  Arcs is not the first game to try and balance ...
# 1  FromSoftware says Shadow of the Erdtree is the...
# 2  Stardew Valley is not only the best farming ga...
# 3  Asgard’s Wrath 2 is the full-fledged VR open-w...
# 4  I don't want to say every CRPG going forward s...
#
#                                          Review_Text  \
# 0  Arcs is not the first game to try and balance ...
# 1  Like the base game did before it, Elden Ring: ...
# 2  More than just a cozy farming sim, eight years...
# 3  Asgard’s Wrath 2 is an open-world action RPG t...
# 4  With crunchy, tactical RPG combat, a memorable...
#
#                                            Long_Text  \
# 0  Space conquest games are ten a penny, includin...
# 1  When I gave Elden Ring a 10 two years ago, I d...
# 2  Editor's Note: This review takes a fresh look ...
# 3  For those who have been patiently waiting on t...
# 4  Every once in a long while, a game comes along...
#
#                                               Quotes  \
# 0                                               None
# 1  According to our count, there are more than 40...
# 2  Multitasking efficiently is a deceptively tens...
# 3  This sequel improves and expands upon just abo...
# 4  This is a world that will rarely tell you, 'No...
#
#                                  Tokenized_Long_Text
# 0  [Space, conquest, games, are, ten, a, penny, ,...
# 1  [When, I, gave, Elden, Ring, a, 10, two, years...
# 2  [Editor, 's, Note, :, This, review, takes, a, ...
# 3  [For, those, who, have, been, patiently, waiti...
# 4  [Every, once, in, a, long, while, ,, a, game, ...

# %% [markdown]
# Weitere vorverarbeitung:
# - kleinbuchstaben
# - lemmatisierung
# - Stoppwörter entfernen
# - Zahlen und Satzzeichen entfernen

# %%
import spacy
from tqdm.notebook import tqdm

tqdm.pandas()


nlp = spacy.load("en_core_web_sm")


def preprocess_text(text):
    if not isinstance(text, str):
        return []

    
    doc = nlp(text.lower()) # kleinbuchstaben
    tokens = [
            token.lemma_ # lemmatisierung
            for token in doc
            if token.is_alpha and not token.is_stop # zahlen entfernen und stopwörter
        ]
    return tokens

df["Preprocessed_Long_Text"] = df["Long_Text"].progress_apply(preprocess_text)
# Out:
#   0%|          | 0/6945 [00:00<?, ?it/s]

# %%
df.head()
# Out:
#                                      ID  \
# 0  aad9a4c3-8a9b-4789-b239-8d6872da6b7e
# 1  3b738a45-14a4-4e9f-9c50-c37458bb5844
# 2  85dfd49f-59ce-45cb-8b86-657c001455de
# 3  dc47b511-7668-4107-b7c0-8c63266ac963
# 4  003f6d65-549f-477c-822b-6f57a8a9105e
#
#                                                  URL           Scraped_at  \
# 0  https://www.ign.com/articles/arcs-board-game-r...  2025-03-30 15:20:27
# 1  https://www.ign.com/articles/elden-ring-shadow...  2025-03-30 15:20:29
# 2  https://www.ign.com/articles/stardew-valley-re...  2025-03-30 15:20:30
# 3  https://www.ign.com/articles/asgards-wrath-2-r...  2025-03-30 15:20:31
# 4  https://www.ign.com/articles/baldurs-gate-3-re...  2025-03-30 15:20:32
#
#               Author                    Posted                  Modified  \
# 0       Matt Thrower  2024-11-13T15:10:01.708Z  2024-11-13T15:20:56.240Z
# 1  Mitchell Saltzman  2024-06-18T14:00:00.000Z  2024-06-25T22:46:45.861Z
# 2     Shailyn Cotten  2024-05-07T16:00:00.000Z  2024-07-12T17:14:15.989Z
# 3     Travis Northup  2023-12-14T14:00:00.000Z  2023-12-14T20:40:01.659Z
# 4        Leana Hafer  2023-08-18T23:32:25.376Z  2024-01-31T19:38:28.947Z
#
#                                           Title  \
# 0                        Arcs Board Game Review
# 1  Elden Ring: Shadow of the Erdtree DLC Review
# 2                  Stardew Valley Review - 2024
# 3                       Asgard’s Wrath 2 Review
# 4                        Baldur's Gate 3 Review
#
#                                             Subtitle  Score  \
# 0           A deviously deep game of space conquest.   10.0
# 1                                       Untarnished.   10.0
# 2  Eight years of impressive updates have grown S...   10.0
# 3  This open-world action RPG sets a new gold sta...   10.0
# 4  A new high-water mark for CRPGs with satisfyin...   10.0
#
#                                              Verdict  \
# 0  Arcs is not the first game to try and balance ...
# 1  FromSoftware says Shadow of the Erdtree is the...
# 2  Stardew Valley is not only the best farming ga...
# 3  Asgard’s Wrath 2 is the full-fledged VR open-w...
# 4  I don't want to say every CRPG going forward s...
#
#                                          Review_Text  \
# 0  Arcs is not the first game to try and balance ...
# 1  Like the base game did before it, Elden Ring: ...
# 2  More than just a cozy farming sim, eight years...
# 3  Asgard’s Wrath 2 is an open-world action RPG t...
# 4  With crunchy, tactical RPG combat, a memorable...
#
#                                            Long_Text  \
# 0  Space conquest games are ten a penny, includin...
# 1  When I gave Elden Ring a 10 two years ago, I d...
# 2  Editor's Note: This review takes a fresh look ...
# 3  For those who have been patiently waiting on t...
# 4  Every once in a long while, a game comes along...
#
#                                               Quotes  \
# 0                                               None
# 1  According to our count, there are more than 40...
# 2  Multitasking efficiently is a deceptively tens...
# 3  This sequel improves and expands upon just abo...
# 4  This is a world that will rarely tell you, 'No...
#
#                                  Tokenized_Long_Text  \
# 0  [Space, conquest, games, are, ten, a, penny, ,...
# 1  [When, I, gave, Elden, Ring, a, 10, two, years...
# 2  [Editor, 's, Note, :, This, review, takes, a, ...
# 3  [For, those, who, have, been, patiently, waiti...
# 4  [Every, once, in, a, long, while, ,, a, game, ...
#
#                               Preprocessed_Long_Text
# 0  [space, conquest, game, penny, include, good, ...
# 1  [give, elden, ring, year, ago, incredible, gam...
# 2  [editor, note, review, take, fresh, look, star...
# 3  [patiently, wait, sideline, vr, reason, couch,...
# 4  [long, game, come, memorable, exciting, fresh,...

# %%
df["Preprocessed_Long_Text"] = df["Preprocessed_Long_Text"].apply(lambda tokens: " ".join(tokens) if isinstance(tokens, list) else "")
# SQLite kann die Liste nicht nehmen, daher einfach wörter getrennt mit " "

# %%
df["Tokenized_Long_Text"] = df["Tokenized_Long_Text"].apply(lambda tokens: " ".join(tokens) if isinstance(tokens, list) else "")

# %%
df.head()
# Out:
#                                      ID  \
# 0  aad9a4c3-8a9b-4789-b239-8d6872da6b7e
# 1  3b738a45-14a4-4e9f-9c50-c37458bb5844
# 2  85dfd49f-59ce-45cb-8b86-657c001455de
# 3  dc47b511-7668-4107-b7c0-8c63266ac963
# 4  003f6d65-549f-477c-822b-6f57a8a9105e
#
#                                                  URL           Scraped_at  \
# 0  https://www.ign.com/articles/arcs-board-game-r...  2025-03-30 15:20:27
# 1  https://www.ign.com/articles/elden-ring-shadow...  2025-03-30 15:20:29
# 2  https://www.ign.com/articles/stardew-valley-re...  2025-03-30 15:20:30
# 3  https://www.ign.com/articles/asgards-wrath-2-r...  2025-03-30 15:20:31
# 4  https://www.ign.com/articles/baldurs-gate-3-re...  2025-03-30 15:20:32
#
#               Author                    Posted                  Modified  \
# 0       Matt Thrower  2024-11-13T15:10:01.708Z  2024-11-13T15:20:56.240Z
# 1  Mitchell Saltzman  2024-06-18T14:00:00.000Z  2024-06-25T22:46:45.861Z
# 2     Shailyn Cotten  2024-05-07T16:00:00.000Z  2024-07-12T17:14:15.989Z
# 3     Travis Northup  2023-12-14T14:00:00.000Z  2023-12-14T20:40:01.659Z
# 4        Leana Hafer  2023-08-18T23:32:25.376Z  2024-01-31T19:38:28.947Z
#
#                                           Title  \
# 0                        Arcs Board Game Review
# 1  Elden Ring: Shadow of the Erdtree DLC Review
# 2                  Stardew Valley Review - 2024
# 3                       Asgard’s Wrath 2 Review
# 4                        Baldur's Gate 3 Review
#
#                                             Subtitle  Score  \
# 0           A deviously deep game of space conquest.   10.0
# 1                                       Untarnished.   10.0
# 2  Eight years of impressive updates have grown S...   10.0
# 3  This open-world action RPG sets a new gold sta...   10.0
# 4  A new high-water mark for CRPGs with satisfyin...   10.0
#
#                                              Verdict  \
# 0  Arcs is not the first game to try and balance ...
# 1  FromSoftware says Shadow of the Erdtree is the...
# 2  Stardew Valley is not only the best farming ga...
# 3  Asgard’s Wrath 2 is the full-fledged VR open-w...
# 4  I don't want to say every CRPG going forward s...
#
#                                          Review_Text  \
# 0  Arcs is not the first game to try and balance ...
# 1  Like the base game did before it, Elden Ring: ...
# 2  More than just a cozy farming sim, eight years...
# 3  Asgard’s Wrath 2 is an open-world action RPG t...
# 4  With crunchy, tactical RPG combat, a memorable...
#
#                                            Long_Text  \
# 0  Space conquest games are ten a penny, includin...
# 1  When I gave Elden Ring a 10 two years ago, I d...
# 2  Editor's Note: This review takes a fresh look ...
# 3  For those who have been patiently waiting on t...
# 4  Every once in a long while, a game comes along...
#
#                                               Quotes  \
# 0                                               None
# 1  According to our count, there are more than 40...
# 2  Multitasking efficiently is a deceptively tens...
# 3  This sequel improves and expands upon just abo...
# 4  This is a world that will rarely tell you, 'No...
#
#                                  Tokenized_Long_Text  \
# 0  Space conquest games are ten a penny , includi...
# 1  When I gave Elden Ring a 10 two years ago , I ...
# 2  Editor 's Note : This review takes a fresh loo...
# 3  For those who have been patiently waiting on t...
# 4  Every once in a long while , a game comes alon...
#
#                               Preprocessed_Long_Text
# 0  space conquest game penny include good war boa...
# 1  give elden ring year ago incredible game raise...
# 2  editor note review take fresh look stardew val...
# 3  patiently wait sideline vr reason couch flail ...
# 4  long game come memorable exciting fresh write ...

# %%
df.to_sql("reviews", conn, if_exists="replace", index=False)
# Out:
# 6945
